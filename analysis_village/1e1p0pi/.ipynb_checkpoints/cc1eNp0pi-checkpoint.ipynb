# %% [markdown]
# ## Pandora $\nu_e$CCN$p$0$\pi^{\pm}$ selection

# %%
import os
import sys

import numpy
import pickle
import uproot

import pandas
pandas.set_option('display.max_columns', None)

import matplotlib.pyplot as plt

import CC1eNp0pi_Cuts as cuts
import CC1eNp0pi_TruthCuts as tcuts

CAFPYANA_PATH = '/exp/icarus/app/users/rtriozzi/cafpyana/'
sys.path.append(CAFPYANA_PATH)
import pyanalib.pandas_helpers

# %% [markdown]
# #### Load data

# %%
# check keys
# pandas.HDFStore(f"{CAFPYANA_PATH}/test_pandora.df").keys()

# %%
CAFPYANA_PATH = '/exp/icarus/app/users/rtriozzi/cafpyana/'
DF_PATH       = f'{CAFPYANA_PATH}/NuMI_NuE_v10_06_00_01p01_1D.df'
#venv_path = os.getenv("PATH")
evtdf = pandas.read_hdf(f'{DF_PATH}', key='evt_0')
hdrdf = pandas.read_hdf(DF_PATH, key='hdr_0')
mcnudf = pandas.read_hdf(DF_PATH, key='mcnu_0')
potdf = pandas.read_hdf(DF_PATH, key='pot_0')

# %%
# merge truth and reco
matchdf = pyanalib.pandas_helpers.multicol_merge(
    evtdf.reset_index(), mcnudf.reset_index(),
    left_on=[("entry", "",""), ("slc","tmatch", "idx", "", "", "")],
    right_on=[("entry", "",""), ("rec.mc.nu..index", "","")], 
    how="left"
) # save all slices!

# %% [markdown]
# #### Event selection

# %%
def SplitByCut(
    df,
    Selection,
    Var,
    Cuts
):
    CutDFs = []
    
    for Cut in Cuts:
        if Selection is None:
            CutDFs.append(df.loc[Cut, Var])
        else:
            CutDFs.append(df.loc[Selection & Cut, Var])

    return CutDFs

# %%
Var = ("slc","truth","E")

width = 0.2
n, bins, _ = plt.hist(evtdf.loc[:, Var], bins=numpy.arange(0, 6+width, width))

plt.show()
# Out:
# /tmp/ipykernel_1078/855314638.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.
#   n, bins, _ = plt.hist(evtdf.loc[:, Var], bins=numpy.arange(0, 6+width, width))
# /cvmfs/larsoft.opensciencegrid.org/products/numpy/v1_24_3/Linux64bit+3.10-2.17-e26-p3915/lib/python3.9/site-packages/numpy/lib/histograms.py:461: RuntimeWarning: invalid value encountered in cast
#   a.searchsorted(v[:-1], 'left'),
# /cvmfs/larsoft.opensciencegrid.org/products/numpy/v1_24_3/Linux64bit+3.10-2.17-e26-p3915/lib/python3.9/site-packages/numpy/lib/histograms.py:462: RuntimeWarning: invalid value encountered in cast
#   a.searchsorted(v[-1:], 'right')

# %%
ChannelLabels = ['$\\nu_e$CC', '$\\nu_\mu$CC', '$\\nu$NC', 'OoFV', 'Cosmic']
Cuts = [
    tcuts.kIsNuE(evtdf) & tcuts.kIsCC(evtdf),
    tcuts.kIsNuMu(evtdf) & tcuts.kIsCC(evtdf),
    ~tcuts.kIsCC(evtdf) & tcuts.kIsTrueFV(evtdf),
    ~tcuts.kIsTrueFV(evtdf) & tcuts.kIsNu(evtdf),
    ~tcuts.kIsNu(evtdf)
]

# %%
ChannelLabels = ['FV', 'non-FV']
Cuts = [
    tcuts.kIsTrueFV(evtdf),
    ~tcuts.kIsTrueFV(evtdf)
]

# %%
Var = ("slc","truth","E")

width = 0.2
evtdf_split = SplitByCut(evtdf, None, Var, Cuts)
n, bins, _ = plt.hist(evtdf_split, bins=numpy.arange(0, 5+width, width), stacked=True, label=ChannelLabels)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1078/4175055872.py:11: PerformanceWarning: indexing past lexsort depth may impact performance.
#   CutDFs.append(df.loc[Cut, Var])
# /exp/icarus/app/users/rtriozzi/cafpyana/envs/venv_py39_cafpyana/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6973: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /exp/icarus/app/users/rtriozzi/cafpyana/envs/venv_py39_cafpyana/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6974: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %%
Var = ("slc","barycenterFM","flashTime")

width = 0.2
evtdf_split = SplitByCut(evtdf, None, Var, Cuts)
n, bins, _ = plt.hist(evtdf_split, bins=numpy.arange(-10, 20+width, width), stacked=True, label=ChannelLabels)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1078/4175055872.py:11: PerformanceWarning: indexing past lexsort depth may impact performance.
#   CutDFs.append(df.loc[Cut, Var])

# %%
var = ("slc","truth","E")
truthcut = tcuts.kIsNuE(evtdf) & tcuts.kIsCC(evtdf)
 
binning = numpy.concatenate(
    (numpy.arange(0, 2+0.2, 0.2),
    numpy.arange(2+0.4, 4+0.4, 0.4))
)

# truth
n, bins, _ = plt.hist(evtdf.loc[truthcut, var], bins=binning, histtype='step', lw=1.5, ec='black', label='FV $\\nu_e$CC')

# reco
recocut = cuts.kVertexInFV(evtdf) & cuts.kNotClearCosmic(evtdf)
n, bins, _ = plt.hist(evtdf.loc[truthcut & recocut, var], bins=binning, histtype='step', lw=1.5, label='Pre-selection')

#recocut = cuts.kVertexInFV(evtdf) & cuts.kNotClearCosmic(evtdf) & cuts.kFlashMatch(evtdf)
#n, bins, _ = plt.hist(evtdf.loc[truthcut & recocut, var], bins=binning, histtype='step', lw=1.5, label='Pre-selection')

#recocut = cuts.kVertexInFV(evtdf) & cuts.kNotClearCosmic(evtdf) & cuts.kLargestRecoShower_EnergyCut(evtdf)
#n, bins, _ = plt.hist(evtdf.loc[truthcut & recocut, var], bins=binning, histtype='step', lw=1.5, label='Electron ID')

'''
channelLabels = ['$\\nu_e$CC', '$\\nu_\mu$CC', '$\\nu$NC', 'OoFV', 'Cosmic']
channels = [
    tcuts.kIsNuE(evtdf) & tcuts.kIsCC(evtdf),
    tcuts.kIsNuMu(evtdf) & tcuts.kIsCC(evtdf),
    ~tcuts.kIsCC(evtdf) & tcuts.kIsTrueFV(evtdf),
    ~tcuts.kIsTrueFV(evtdf) & tcuts.kIsNu(evtdf),
    ~tcuts.kIsNu(evtdf)
]

evtdf_split = SplitByCut(evtdf, truthcut & recocut, var, channels)
n, bins, _ = plt.hist(evtdf_split, bins=numpy.arange(0, 5+width, width), stacked=True, label=channelLabels)
'''

plt.legend()
# Out:
# /tmp/ipykernel_1115/3628273290.py:10: PerformanceWarning: indexing past lexsort depth may impact performance.
#   n, bins, _ = plt.hist(evtdf.loc[truthcut, var], bins=binning, histtype='step', lw=1.5, ec='black', label='FV $\\nu_e$CC')
# /tmp/ipykernel_1115/3628273290.py:14: PerformanceWarning: indexing past lexsort depth may impact performance.
#   n, bins, _ = plt.hist(evtdf.loc[truthcut & recocut, var], bins=binning, histtype='step', lw=1.5, label='Pre-selection')

# %%
# to do: add variables and recreate dfs
# to do: finish implementing cuts in cafpyana
# to do: define signal more precisely
# to do: develop efficiency analysis: look at matchdf, probably useful to select signal first so it's faster

# %%
# print(evtdf.columns.tolist())
